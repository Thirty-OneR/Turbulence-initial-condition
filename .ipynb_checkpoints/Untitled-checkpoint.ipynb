# %%
import numpy as np
import yt

# %%
ds=yt.load("Data_000000")
# Out:
# yt : [WARNING  ] 2019-03-08 17:55:28,230 Cannot determine code units ==> Use units_override to specify the units
# yt : [WARNING  ] 2019-03-08 17:55:28,231 Assuming length unit = 1.0 cm
# yt : [WARNING  ] 2019-03-08 17:55:28,232 Assuming time unit = 1.0 s
# yt : [WARNING  ] 2019-03-08 17:55:28,233 Assuming mass unit = 1.0 g
# yt : [INFO     ] 2019-03-08 17:55:28,250 Parameters: current_time              = 0.0
# yt : [INFO     ] 2019-03-08 17:55:28,251 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2019-03-08 17:55:28,252 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-03-08 17:55:28,254 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2019-03-08 17:55:28,256 Parameters: cosmological_simulation   = 0

# %%
ds2=ds.r[:,:,:]
j=ds2.integrate("density",axis="x")
j.plot()
# Out:
# yt : [INFO     ] 2019-03-08 17:59:39,667 Projection completed
# yt : [INFO     ] 2019-03-08 17:59:39,668 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-03-08 17:59:39,669 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-03-08 17:59:39,670 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
k=ds2.sum("density",axis="x")
k.plot()
# Out:
# yt : [INFO     ] 2019-03-08 18:00:07,641 Projection completed
# yt : [INFO     ] 2019-03-08 18:00:07,643 xlim = 0.000000 1.000000
# yt : [INFO     ] 2019-03-08 18:00:07,644 ylim = 0.000000 1.000000
# yt : [INFO     ] 2019-03-08 18:00:07,646 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ds2.max("density"), ds2.min("density")
# Out:
# (2.733713150024414 g/cm**3, 1.8455424424246303e-06 g/cm**3)

# %%
ds2.max("velocity_x"), ds2.min("velocity_x")
# Out:
# (1.0964801750546076 cm/s, -1.4709210787551692 cm/s)

# %%
ds2.max("velocity_y"), ds2.min("velocity_y")
# Out:
# (1.395901934775502 cm/s, -2.3914163514195867 cm/s)

# %%
ds2.max("velocity_z"), ds2.min("velocity_z")
# Out:
# (1.9095241137142844 cm/s, -2.894469193238724 cm/s)
